# %% [markdown]
# <a href="https://colab.research.google.com/github/sousalorhany56-pixel/TrabalhoLorhany/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip list --format=columns
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.13.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.4
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
# !python
# Out:
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %%
counter = 0
while counter <5:
  print(counter)
  counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
example_dict={}

example_dict['apples']=5
example_dict['oranges']=8
example_dict['bananas']=13

example_dict
# Out:
# {'apples': 5, 'oranges': 8, 'bananas': 13}

# %%
dict_to_list= list(example_dict.values())

dict_to_list
# Out:
# [5, 8, 13]

# %%
import pandas as pd
from google.colab import files

#passo a: comando para abrir a janela de upload do arquivo
print('por favor, selecione o arquivo.xls baixado:')
uploaded = files.upload()

#passo b:ler o arquivo usado pandas
#  'uploaded'
file_name = next(iter(uploaded)) # Pega o nome do primeiro arquivo carregado
df = pd.read_excel(uploaded[file_name])

#passo c : visualiar as primeiras linhas df.head()
df.head()
# Out:
# por favor, selecione o arquivo.xls baixado:
#      <input type="file" id="files-41add6ac-ff74-4d85-9bb1-43dddc6d6c99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41add6ac-ff74-4d85-9bb1-43dddc6d6c99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import pandas as pd
from google.colab import files

#passo a: comando para abrir a janela de upload do arquivo
print('por favor, selecione o arquivo.xls baixado:')
uploaded = files.upload()

#passo b:ler o arquivo usado pandas
file_name = next(iter(uploaded)) # Pega o nome do primeiro arquivo carregado
df = pd.read_excel(uploaded[file_name])

# mostra (linhas , colunas)
print(df.shape)

# mostra o nome de todas as colunas
print(df.columns)
# Out:
# por favor, selecione o arquivo.xls baixado:
#      <input type="file" id="files-3c87ff59-6c06-4cd5-9917-e563f2022a18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c87ff59-6c06-4cd5-9917-e563f2022a18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Jupyter notebook_Lorhany Fernandes

#Até aqui, estou achando a atividade bastante interessante, especialmente a facilidade de carregar dados usando o pandas e a interface visual do notebook.

#Também é possível usar formatações como *negrito, *itálico ou estilo de código.

print('celula executada com suceso')
# Out:
# celula executada com suceso

# %%
import pandas as pd

df= pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.dtypes
# Out:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# dtype: object

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
